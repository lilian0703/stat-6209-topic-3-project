# %% [markdown]
# # Step 1: Install the environment

# %%
# !nvidia-smi
# !pip install --upgrade protobuf==5.29.1
# !pip install numpy==1.26.0
# !pip install wandb==0.16.3
# !pip install --upgrade accelerate diffusers[training]
# !pip install -q transformers datasets peft bitsandbytes xformers huggingface_hub
# Out:
# Sat Apr 18 05:23:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Collecting protobuf==5.29.1
#   Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# Successfully installed protobuf-5.29.1
# Collecting numpy==1.26.0
#   Downloading numpy-1.26.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 2.8 MB/s eta 0:00:00
# Downloading numpy-1.26.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 75.5 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.0 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.0 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.0 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.0 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.0 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.0 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.0 which is incompatible.
# Successfully installed numpy-1.26.0
# Collecting wandb==0.16.3
#   Downloading wandb-0.16.3-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (8.3.2)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (3.1.46)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (2.32.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (2.57.0)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.16.3)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (6.0.3)
# Collecting setproctitle (from wandb==0.16.3)
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (75.2.0)
# Collecting appdirs>=1.4.3 (from wandb==0.16.3)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting protobuf!=4.21.0,<5,>=3.19.0 (from wandb==0.16.3)
#   Downloading protobuf-4.25.9-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from docker-pycreds>=0.4.0->wandb==0.16.3) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.3) (4.0.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.3) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.3) (2026.2.25)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.3) (5.0.3)
# Downloading wandb-0.16.3-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 43.4 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading protobuf-4.25.9-cp37-abi3-manylinux2014_x86_64.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 28.2 MB/s eta 0:00:00
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Installing collected packages: appdirs, setproctitle, protobuf, docker-pycreds, wandb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.1
#     Uninstalling protobuf-5.29.1:
#       Successfully uninstalled protobuf-5.29.1
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.25.1
#     Uninstalling wandb-0.25.1:
#       Successfully uninstalled wandb-0.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# Successfully installed appdirs-1.4.4 docker-pycreds-0.4.0 protobuf-4.25.9 setproctitle-1.3.7 wandb-0.16.3
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: diffusers[training] in /usr/local/lib/python3.12/dist-packages (0.37.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.10.0+cu128)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (1.10.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (3.25.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (2.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (11.3.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (4.0.0)
# Collecting protobuf<4,>=3.20.3 (from diffusers[training])
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (2.19.0)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (3.1.6)
# Requirement already satisfied: peft>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (0.18.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (1.0.26)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[training]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[training]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[training]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[training]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers[training]) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft>=0.17.0->diffusers[training]) (5.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate) (1.5.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (0.70.16)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers[training]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers[training]) (2.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->diffusers[training]) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2->diffusers[training]) (3.0.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (3.10.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (3.1.8)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm->diffusers[training]) (0.25.0+cu128)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (3.13.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->diffusers[training]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->diffusers[training]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->diffusers[training]) (2026.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->peft>=0.17.0->diffusers[training]) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->peft>=0.17.0->diffusers[training]) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (1.23.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.9
#     Uninstalling protobuf-4.25.9:
#       Successfully uninstalled protobuf-4.25.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-monitoring 2.30.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-bigquery-connection 1.21.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-translate 3.26.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# googleapis-common-protos 1.74.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-dataproc 5.26.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-pubsub 2.37.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-logging 3.15.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-audit-log 0.5.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-bigquery-storage 2.37.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-resource-manager 1.17.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# proto-plus 1.27.2 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.17.3 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# google-cloud-datastore 2.24.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-language 2.20.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-api-core 2.30.3 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-secret-manager 2.27.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-appengine-logging 1.9.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-trace 1.19.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-iam 2.22.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-speech 2.38.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-functions 1.23.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-dataplex 2.18.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grpc-google-iam-v1 0.14.4 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 111.8 MB/s eta 0:00:00

# %% [markdown]
# # Step 2: Upload and check the training data

# %%
import os
image_dir = "/content/sticker_images"
os.makedirs(image_dir, exist_ok=True)

# %%
images = os.listdir(image_dir)
print(f"find {len(images)} picturs：{images[:]}")
if len(images) == 0:
    raise Exception("upload /content/sticker_images first！")
# Out:
# find 5 picturs：['watercolor-hedgehog.jpg', 'watercolor-rabbit.jpg', 'watercolor-tiger.png', 'watercolor-goat.png', 'watercolor-wolf.jpg']

# %% [markdown]
# # Step 3: Diffusers

# %%
import os
os.environ["WANDB_DISABLED"] = "true"
# !git clone https://github.com/huggingface/diffusers.git
# %cd /content/diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 120319, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 120319 (delta 71), reused 33 (delta 33), pack-reused 120213 (from 3)
# Receiving objects: 100% (120319/120319), 93.53 MiB | 26.87 MiB/s, done.
# Resolving deltas: 100% (89627/89627), done.
# /content/diffusers

# %% [markdown]
# # Step 4: Training Lora

# %%
# %cd /content/diffusers
# !pip install -e ".[torch]"
import diffusers
# Out:
# /content/diffusers
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (3.25.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (1.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (2.32.4)
# Collecting safetensors>=0.8.0-rc.0 (from diffusers==0.38.0.dev0)
#   Downloading safetensors-0.8.0rc0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (11.3.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (2.10.0+cu128)
# Requirement already satisfied: accelerate>=0.31.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (1.13.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers==0.38.0.dev0) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers==0.38.0.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers==0.38.0.dev0) (6.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.38.0.dev0) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.38.0.dev0) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.38.0.dev0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.38.0.dev0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers==0.38.0.dev0) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.4->diffusers==0.38.0.dev0) (1.5.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers==0.38.0.dev0) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.38.0.dev0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.38.0.dev0) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4->diffusers==0.38.0.dev0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4->diffusers==0.38.0.dev0) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (0.1.2)
# Downloading safetensors-0.8.0rc0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.1/509.1 kB 12.8 MB/s eta 0:00:00
# Building wheels for collected packages: diffusers
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.38.0.dev0-0.editable-py3-none-any.whl size=11406 sha256=055909a162a0a9b6068fb5a69e9a59eac4ed67b3f7cadb501fb003befc89e589
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xl44wn83/wheels/8a/fc/09/385efb77b455b2fd4a656c950079c93147e1f50ae614e51beb
# Successfully built diffusers
# Installing collected packages: safetensors, diffusers
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.37.1
#     Uninstalling diffusers-0.37.1:
#       Successfully uninstalled diffusers-0.37.1
# Successfully installed diffusers-0.38.0.dev0 safetensors-0.8.0rc0

# %%
# clean the history
# !rm -rf /content/lora_sticker_model

# confirm the parameters
# !python examples/dreambooth/train_dreambooth_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --instance_data_dir="/content/sticker_images" \
  --output_dir="/content/lora_sticker_model" \
  --instance_prompt="a sks sticker style" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=1200 \
  --checkpointing_steps=200 \
  --mixed_precision="fp16" \
  --use_8bit_adam
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# tokenizer_config.json: 100% 806/806 [00:00<00:00, 3.54MB/s]
# vocab.json: 1.06MB [00:00, 42.0MB/s]
# merges.txt: 525kB [00:00, 115MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.13MB/s]
# config.json: 100% 617/617 [00:00<00:00, 3.28MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# scheduler_config.json: 100% 308/308 [00:00<00:00, 1.28MB/s]
# {'rescale_betas_zero_snr', 'dynamic_thresholding_ratio', 'prediction_type', 'timestep_spacing', 'thresholding', 'variance_type', 'sample_max_value', 'clip_sample_range'} was not found in config. Values will be initialized to default values.
# text_encoder/model.safetensors: 100% 492M/492M [00:05<00:00, 94.2MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 1222.27it/s, Materializing param=text_model.final_layer_norm.weight]
# CLIPTextModel LOAD REPORT from: runwayml/stable-diffusion-v1-5
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json: 100% 547/547 [00:00<00:00, 3.50MB/s]
# vae/diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 151MB/s]
# {'shift_factor', 'use_post_quant_conv', 'latents_mean', 'use_quant_conv', 'latents_std', 'mid_block_add_attention', 'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# config.json: 100% 743/743 [00:00<00:00, 3.30MB/s]
# unet/diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:35<00:00, 97.1MB/s]
# {'time_embedding_act_fn', 'resnet_skip_time_act', 'conv_out_kernel', 'num_class_embeds', 'mid_block_type', 'cross_attention_norm', 'time_embedding_type', 'projection_class_embeddings_input_dim', 'dual_cross_attention', 'mid_block_only_cross_attention', 'resnet_out_scale_factor', 'only_cross_attention', 'transformer_layers_per_block', 'encoder_hid_dim_type', 'dropout', 'time_embedding_dim', 'upcast_attention', 'num_attention_heads', 'timestep_post_act', 'use_linear_projection', 'resnet_time_scale_shift', 'attention_type', 'addition_embed_type_num_heads', 'reverse_transformer_layers_per_block', 'addition_embed_type', 'class_embed_type', 'conv_in_kernel', 'encoder_hid_dim', 'time_cond_proj_dim', 'class_embeddings_concat', 'addition_time_embed_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# 2026-04-18 05:27:46.189263: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776490066.505682   11273 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776490066.604705   11273 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776490067.229633   11273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776490067.229674   11273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776490067.229682   11273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776490067.229688   11273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Steps:  17% 200/1200 [04:03<18:22,  1.10s/it, loss=0.693, lr=0.0001]Model weights saved in /content/lora_sticker_model/checkpoint-200/pytorch_lora_weights.safetensors
# Steps:  33% 400/1200 [08:15<15:01,  1.13s/it, loss=0.226, lr=0.0001]Model weights saved in /content/lora_sticker_model/checkpoint-400/pytorch_lora_weights.safetensors
# Steps:  50% 600/1200 [12:26<10:59,  1.10s/it, loss=0.0462, lr=0.0001]Model weights saved in /content/lora_sticker_model/checkpoint-600/pytorch_lora_weights.safetensors
# Steps:  67% 800/1200 [16:38<07:18,  1.10s/it, loss=0.0117, lr=0.0001]Model weights saved in /content/lora_sticker_model/checkpoint-800/pytorch_lora_weights.safetensors
# Steps:  83% 1000/1200 [20:49<03:42,  1.11s/it, loss=0.0458, lr=0.0001]Model weights saved in /content/lora_sticker_model/checkpoint-1000/pytorch_lora_weights.safetensors
# Steps: 100% 1200/1200 [25:00<00:00,  1.09s/it, loss=0.01, lr=0.0001]Model weights saved in /content/lora_sticker_model/checkpoint-1200/pytorch_lora_weights.safetensors
# Steps: 100% 1200/1200 [25:00<00:00,  1.09s/it, loss=0.00203, lr=0.0001]Model weights saved in /content/lora_sticker_model/pytorch_lora_weights.safetensors
#
# model_index.json: 100% 541/541 [00:00<00:00, 2.26MB/s]
#
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
#
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading (incomplete total...):   0% 0.00/342 [00:00<?, ?B/s]
# Downloading (incomplete total...): 100% 342/342 [00:00<00:00, 1.71kB/s]
#
# Fetching 15 files:   7% 1/15 [00:00<00:02,  5.24it/s]
# Downloading (incomplete total...):   0% 5.07k/1.22G [00:00<198:01:00, 1.71kB/s]
# Downloading (incomplete total...):   0% 5.07k/1.22G [00:00<32:34:03, 10.4kB/s]
# Downloading (incomplete total...):   6% 67.2M/1.22G [00:01<00:22, 50.1MB/s]
# Downloading (incomplete total...):  11% 134M/1.22G [00:02<00:14, 74.3MB/s]
# Downloading (incomplete total...):  21% 256M/1.22G [00:05<00:22, 43.1MB/s]
# Downloading (incomplete total...): 1.22GB [00:12, 114MB/s]
#
# Fetching 15 files: 100% 15/15 [00:12<00:00,  1.24it/s]
#
# Download complete: : 1.22GB [00:12, 114MB/s]              {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.float16.
# {'shift_factor', 'use_post_quant_conv', 'latents_mean', 'use_quant_conv', 'latents_std', 'mid_block_add_attention', 'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  29% 2/7 [00:01<00:03,  1.31it/s]Instantiating UNet2DConditionModel model under default dtype torch.float16.
# {'time_embedding_act_fn', 'resnet_skip_time_act', 'conv_out_kernel', 'num_class_embeds', 'mid_block_type', 'cross_attention_norm', 'time_embedding_type', 'projection_class_embeddings_input_dim', 'dual_cross_attention', 'mid_block_only_cross_attention', 'resnet_out_scale_factor', 'only_cross_attention', 'transformer_layers_per_block', 'encoder_hid_dim_type', 'dropout', 'time_embedding_dim', 'upcast_attention', 'num_attention_heads', 'timestep_post_act', 'use_linear_projection', 'resnet_time_scale_shift', 'attention_type', 'addition_embed_type_num_heads', 'reverse_transformer_layers_per_block', 'addition_embed_type', 'class_embed_type', 'conv_in_kernel', 'encoder_hid_dim', 'time_cond_proj_dim', 'class_embeddings_concat', 'addition_time_embed_dim'} was not found in config. Values will be initialized to default values.
# Download complete: : 1.22GB [00:13, 88.9MB/s]
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43% 3/7 [00:14<00:23,  5.82s/it]
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
# Loading weights:   1% 1/196 [00:00<00:00, 7854.50it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 1/196 [00:00<00:00, 2962.08it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 210.69it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 206.89it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   2% 3/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   2% 3/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.bias]
# Loading weights:   2% 3/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.bias]
# Loading weights:   2% 4/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.weight]
# Loading weights:   2% 4/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.weight]
# Loading weights:   3% 5/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.bias]
# Loading weights:   3% 5/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.bias]
# Loading weights:   3% 6/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.weight]
# Loading weights:   3% 6/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.weight]
# Loading weights:   4% 7/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.bias]
# Loading weights:   4% 7/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.bias]
# Loading weights:   4% 8/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.weight]
# Loading weights:   4% 8/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.weight]
# Loading weights:   5% 9/196 [00:01<01:10,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.bias]
# Loading weights:   5% 9/196 [00:01<01:10,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.bias]
# Loading weights:   5% 10/196 [00:01<01:10,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.weight]
# Loading weights:   5% 10/196 [00:01<01:10,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.weight]
# Loading weights:   6% 11/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.bias]
# Loading weights:   6% 11/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.bias]
# Loading weights:   6% 12/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.weight]
# Loading weights:   6% 12/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.weight]
# Loading weights:   7% 13/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.bias]
# Loading weights:   7% 13/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.bias]
# Loading weights:   7% 14/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.weight]
# Loading weights:   7% 14/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.weight]
# Loading weights:   8% 15/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.bias]
# Loading weights:   8% 15/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.bias]
# Loading weights:   8% 16/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.weight]
# Loading weights:   8% 16/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.weight]
# Loading weights:   9% 17/196 [00:01<01:07,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.bias]
# Loading weights:   9% 17/196 [00:01<01:07,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.bias]
# Loading weights:   9% 18/196 [00:01<01:07,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.weight]
# Loading weights:   9% 18/196 [00:01<01:07,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.weight]
# Loading weights:  10% 19/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.bias]
# Loading weights:  10% 19/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.bias]
# Loading weights:  10% 20/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.weight]
# Loading weights:  10% 20/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.weight]
# Loading weights:  11% 21/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.bias]
# Loading weights:  11% 21/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.bias]
# Loading weights:  11% 22/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.weight]
# Loading weights:  11% 22/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.weight]
# Loading weights:  12% 23/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.bias]
# Loading weights:  12% 23/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.bias]
# Loading weights:  12% 24/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.weight]
# Loading weights:  12% 24/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.weight]
# Loading weights:  13% 25/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.bias]
# Loading weights:  13% 25/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.bias]
# Loading weights:  13% 26/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.weight]
# Loading weights:  13% 26/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.weight]
# Loading weights:  14% 27/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.bias]
# Loading weights:  14% 27/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.bias]
# Loading weights:  14% 28/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.weight]
# Loading weights:  14% 28/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.weight]
# Loading weights:  15% 29/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.bias]
# Loading weights:  15% 29/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.bias]
# Loading weights:  15% 30/196 [00:01<01:02,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.weight]
# Loading weights:  15% 30/196 [00:01<01:02,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.weight]
# Loading weights:  16% 31/196 [00:01<01:02,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.bias]
# Loading weights:  16% 31/196 [00:01<01:02,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.bias]
# Loading weights:  16% 32/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.weight]
# Loading weights:  16% 32/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.weight]
# Loading weights:  17% 33/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.bias]
# Loading weights:  17% 33/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.bias]
# Loading weights:  17% 34/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.weight]
# Loading weights:  17% 34/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.weight]
# Loading weights:  18% 35/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.bias]
# Loading weights:  18% 35/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.bias]
# Loading weights:  18% 36/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.weight]
# Loading weights:  18% 36/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.weight]
# Loading weights:  19% 37/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.bias]
# Loading weights:  19% 37/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.bias]
# Loading weights:  19% 38/196 [00:01<00:59,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.weight]
# Loading weights:  19% 38/196 [00:01<00:59,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.weight]
# Loading weights:  20% 39/196 [00:01<00:59,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.bias]
# Loading weights:  20% 39/196 [00:01<00:59,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.bias]
# Loading weights:  20% 40/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.weight]
# Loading weights:  20% 40/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.weight]
# Loading weights:  21% 41/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.bias]
# Loading weights:  21% 41/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.bias]
# Loading weights:  21% 42/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.weight]
# Loading weights:  21% 42/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.weight]
# Loading weights:  22% 43/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.bias]
# Loading weights:  22% 43/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.bias]
# Loading weights:  22% 44/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.weight]
# Loading weights:  22% 44/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.weight]
# Loading weights:  23% 45/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.bias]
# Loading weights:  23% 45/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.bias]
# Loading weights:  23% 46/196 [00:01<00:56,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.weight]
# Loading weights:  23% 46/196 [00:01<00:56,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.weight]
# Loading weights:  24% 47/196 [00:01<00:56,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.bias]
# Loading weights:  24% 47/196 [00:01<00:56,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.bias]
# Loading weights:  24% 48/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.weight]
# Loading weights:  24% 48/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.weight]
# Loading weights:  25% 49/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.bias]
# Loading weights:  25% 49/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.bias]
# Loading weights:  26% 50/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.weight]
# Loading weights:  26% 50/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.weight]
# Loading weights:  26% 51/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.bias]
# Loading weights:  26% 51/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.bias]
# Loading weights:  27% 52/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.weight]
# Loading weights:  27% 52/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.weight]
# Loading weights:  27% 53/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.bias]
# Loading weights:  27% 53/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.bias]
# Loading weights:  28% 54/196 [00:01<00:53,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.weight]
# Loading weights:  28% 54/196 [00:01<00:53,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.weight]
# Loading weights:  28% 55/196 [00:01<00:53,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.bias]
# Loading weights:  28% 55/196 [00:01<00:53,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.bias]
# Loading weights:  29% 56/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.weight]
# Loading weights:  29% 56/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.weight]
# Loading weights:  29% 57/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.bias]
# Loading weights:  29% 57/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.bias]
# Loading weights:  30% 58/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.weight]
# Loading weights:  30% 58/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.weight]
# Loading weights:  30% 59/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.bias]
# Loading weights:  30% 59/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.bias]
# Loading weights:  31% 60/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.weight]
# Loading weights:  31% 60/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.weight]
# Loading weights:  31% 61/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.bias]
# Loading weights:  31% 61/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.bias]
# Loading weights:  32% 62/196 [00:01<00:50,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.weight]
# Loading weights:  32% 62/196 [00:01<00:50,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.weight]
# Loading weights:  32% 63/196 [00:01<00:50,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.bias]
# Loading weights:  32% 63/196 [00:01<00:50,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.bias]
# Loading weights:  33% 64/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.weight]
# Loading weights:  33% 64/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.weight]
# Loading weights:  33% 65/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.bias]
# Loading weights:  33% 65/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.bias]
# Loading weights:  34% 66/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.weight]
# Loading weights:  34% 66/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.weight]
# Loading weights:  34% 67/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.bias]
# Loading weights:  34% 67/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.bias]
# Loading weights:  35% 68/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.weight]
# Loading weights:  35% 68/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.weight]
# Loading weights:  35% 69/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.bias]
# Loading weights:  35% 69/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.bias]
# Loading weights:  36% 70/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.weight]
# Loading weights:  36% 70/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.weight]
# Loading weights:  36% 71/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.bias]
# Loading weights:  36% 71/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.bias]
# Loading weights:  37% 72/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.weight]
# Loading weights:  37% 72/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.weight]
# Loading weights:  37% 73/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.bias]
# Loading weights:  37% 73/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.bias]
# Loading weights:  38% 74/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.weight]
# Loading weights:  38% 74/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.weight]
# Loading weights:  38% 75/196 [00:01<00:45,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.bias]
# Loading weights:  38% 75/196 [00:01<00:45,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.bias]
# Loading weights:  39% 76/196 [00:01<00:45,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.weight]
# Loading weights:  39% 76/196 [00:01<00:45,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.weight]
# Loading weights:  39% 77/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.bias]
# Loading weights:  39% 77/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.bias]
# Loading weights:  40% 78/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.weight]
# Loading weights:  40% 78/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.weight]
# Loading weights:  40% 79/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.bias]
# Loading weights:  40% 79/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.bias]
# Loading weights:  41% 80/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.weight]
# Loading weights:  41% 80/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.weight]
# Loading weights:  41% 81/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.bias]
# Loading weights:  41% 81/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.bias]
# Loading weights:  42% 82/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.weight]
# Loading weights:  42% 82/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.weight]
# Loading weights:  42% 83/196 [00:01<00:42,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.bias]
# Loading weights:  42% 83/196 [00:01<00:42,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.bias]
# Loading weights:  43% 84/196 [00:01<00:42,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
# Loading weights:  43% 84/196 [00:01<00:42,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
# Loading weights:  43% 85/196 [00:01<00:41,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.bias]
# Loading weights:  43% 85/196 [00:01<00:41,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.bias]
# Loading weights:  44% 86/196 [00:01<00:41,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.weight]
# Loading weights:  44% 86/196 [00:01<00:41,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.weight]
# Loading weights:  44% 87/196 [00:01<00:41,  2.65it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.bias]
# Loading weights:  44% 87/196 [00:01<00:41,  2.65it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.bias]
# Loading weights:  45% 88/196 [00:01<00:40,  2.65it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.weight]
# Loading weights:  45% 88/196 [00:01<00:40,  2.65it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.weight]
# Loading weights:  45% 89/196 [00:01<00:40,  2.65it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.bias]
# Loading weights:  45% 89/196 [00:01<00:40,  2.65it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.bias]
# Loading weights:  46% 90/196 [00:01<00:40,  2.65it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.weight]
# Loading weights:  46% 90/196 [00:01<00:40,  2.65it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.weight]
# Loading weights:  46% 91/196 [00:01<00:39,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.bias]
# Loading weights:  46% 91/196 [00:01<00:39,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.bias]
# Loading weights:  47% 92/196 [00:01<00:39,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.weight]
# Loading weights:  47% 92/196 [00:01<00:39,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.weight]
# Loading weights:  47% 93/196 [00:01<00:38,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.bias]
# Loading weights:  47% 93/196 [00:01<00:38,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.bias]
# Loading weights:  48% 94/196 [00:01<00:38,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.weight]
# Loading weights:  48% 94/196 [00:01<00:38,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.weight]
# Loading weights:  48% 95/196 [00:01<00:38,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.bias]
# Loading weights:  48% 95/196 [00:01<00:38,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.bias]
# Loading weights:  49% 96/196 [00:01<00:37,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.weight]
# Loading weights:  49% 96/196 [00:01<00:37,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.weight]
# Loading weights:  49% 97/196 [00:01<00:37,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.bias]
# Loading weights:  49% 97/196 [00:01<00:37,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.bias]
# Loading weights:  50% 98/196 [00:01<00:37,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.weight]
# Loading weights:  50% 98/196 [00:01<00:37,  2.65it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.weight]
# Loading weights:  51% 99/196 [00:01<00:36,  2.65it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.bias]
# Loading weights:  51% 99/196 [00:01<00:36,  2.65it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.bias]
# Loading weights:  51% 100/196 [00:01<00:36,  2.65it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.weight]
# Loading weights:  51% 100/196 [00:01<00:36,  2.65it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.weight]
# Loading weights:  52% 101/196 [00:01<00:35,  2.65it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.bias]
# Loading weights:  52% 101/196 [00:01<00:35,  2.65it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.bias]
# Loading weights:  52% 102/196 [00:01<00:35,  2.65it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.weight]
# Loading weights:  52% 102/196 [00:01<00:35,  2.65it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.weight]
# Loading weights:  53% 103/196 [00:01<00:35,  2.65it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.bias]
# Loading weights:  53% 103/196 [00:01<00:35,  2.65it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.bias]
# Loading weights:  53% 104/196 [00:01<00:34,  2.65it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.weight]
# Loading weights:  53% 104/196 [00:01<00:34,  2.65it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.weight]
# Loading weights:  54% 105/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.weight]
# Loading weights:  54% 105/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.bias]
# Loading weights:  54% 105/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.bias]
# Loading weights:  54% 106/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.weight]
# Loading weights:  54% 106/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.weight]
# Loading weights:  55% 107/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.bias]
# Loading weights:  55% 107/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.bias]
# Loading weights:  55% 108/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.weight]
# Loading weights:  55% 108/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.weight]
# Loading weights:  56% 109/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.bias]
# Loading weights:  56% 109/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.bias]
# Loading weights:  56% 110/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.weight]
# Loading weights:  56% 110/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.weight]
# Loading weights:  57% 111/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.bias]
# Loading weights:  57% 111/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.bias]
# Loading weights:  57% 112/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.weight]
# Loading weights:  57% 112/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.weight]
# Loading weights:  58% 113/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.bias]
# Loading weights:  58% 113/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.bias]
# Loading weights:  58% 114/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.weight]
# Loading weights:  58% 114/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.weight]
# Loading weights:  59% 115/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.bias]
# Loading weights:  59% 115/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.bias]
# Loading weights:  59% 116/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.weight]
# Loading weights:  59% 116/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.weight]
# Loading weights:  60% 117/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.bias]
# Loading weights:  60% 117/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.bias]
# Loading weights:  60% 118/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.weight]
# Loading weights:  60% 118/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.weight]
# Loading weights:  61% 119/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.bias]
# Loading weights:  61% 119/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.bias]
# Loading weights:  61% 120/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.weight]
# Loading weights:  61% 120/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.weight]
# Loading weights:  62% 121/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.bias]
# Loading weights:  62% 121/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.bias]
# Loading weights:  62% 122/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.weight]
# Loading weights:  62% 122/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.weight]
# Loading weights:  63% 123/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.bias]
# Loading weights:  63% 123/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.bias]
# Loading weights:  63% 124/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.weight]
# Loading weights:  63% 124/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.weight]
# Loading weights:  64% 125/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.bias]
# Loading weights:  64% 125/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.bias]
# Loading weights:  64% 126/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.weight]
# Loading weights:  64% 126/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.weight]
# Loading weights:  65% 127/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.bias]
# Loading weights:  65% 127/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.bias]
# Loading weights:  65% 128/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.weight]
# Loading weights:  65% 128/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.weight]
# Loading weights:  66% 129/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.bias]
# Loading weights:  66% 129/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.bias]
# Loading weights:  66% 130/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.weight]
# Loading weights:  66% 130/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.weight]
# Loading weights:  67% 131/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.bias]
# Loading weights:  67% 131/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.bias]
# Loading weights:  67% 132/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.weight]
# Loading weights:  67% 132/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.weight]
# Loading weights:  68% 133/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.bias]
# Loading weights:  68% 133/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.bias]
# Loading weights:  68% 134/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.weight]
# Loading weights:  68% 134/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.weight]
# Loading weights:  69% 135/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.bias]
# Loading weights:  69% 135/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.bias]
# Loading weights:  69% 136/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.weight]
# Loading weights:  69% 136/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.weight]
# Loading weights:  70% 137/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.bias]
# Loading weights:  70% 137/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.bias]
# Loading weights:  70% 138/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.weight]
# Loading weights:  70% 138/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.weight]
# Loading weights:  71% 139/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.bias]
# Loading weights:  71% 139/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.bias]
# Loading weights:  71% 140/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.weight]
# Loading weights:  71% 140/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.weight]
# Loading weights:  72% 141/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.bias]
# Loading weights:  72% 141/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.bias]
# Loading weights:  72% 142/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.weight]
# Loading weights:  72% 142/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.weight]
# Loading weights:  73% 143/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.bias]
# Loading weights:  73% 143/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.bias]
# Loading weights:  73% 144/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.weight]
# Loading weights:  73% 144/196 [00:01<00:00, 109.96it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.weight]
# Loading weights:  74% 145/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.weight]
# Loading weights:  74% 145/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.bias]
# Loading weights:  74% 145/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.bias]
# Loading weights:  74% 146/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.weight]
# Loading weights:  74% 146/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.weight]
# Loading weights:  75% 147/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.bias]
# Loading weights:  75% 147/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.bias]
# Loading weights:  76% 148/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.weight]
# Loading weights:  76% 148/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.weight]
# Loading weights:  76% 149/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.bias]
# Loading weights:  76% 149/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.bias]
# Loading weights:  77% 150/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.weight]
# Loading weights:  77% 150/196 [00:01<00:00, 116.27it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.weight]
# ...
# Loading weights:  87% 346/396 [00:04<00:00, 80.08it/s, Materializing param=vision_model.vision_model.encoder.layers.21.layer_norm2.bias]
# Loading weights:  87% 346/396 [00:04<00:00, 80.08it/s, Materializing param=vision_model.vision_model.encoder.layers.21.layer_norm2.bias]
# Loading weights:  88% 347/396 [00:04<00:00, 80.08it/s, Materializing param=vision_model.vision_model.encoder.layers.21.layer_norm2.weight]
# Loading weights:  88% 347/396 [00:04<00:00, 80.08it/s, Materializing param=vision_model.vision_model.encoder.layers.21.layer_norm2.weight]
# Loading weights:  88% 348/396 [00:04<00:00, 80.08it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.bias]
# Loading weights:  88% 348/396 [00:04<00:00, 80.08it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.bias]
# Loading weights:  88% 349/396 [00:04<00:00, 80.08it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.weight]
# Loading weights:  88% 349/396 [00:04<00:00, 80.08it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.weight]
# Loading weights:  88% 350/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.weight]
# Loading weights:  88% 350/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc2.bias]
# Loading weights:  88% 350/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc2.bias]
# Loading weights:  89% 351/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc2.weight]
# Loading weights:  89% 351/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc2.weight]
# Loading weights:  89% 352/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.k_proj.bias]
# Loading weights:  89% 352/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.k_proj.bias]
# Loading weights:  89% 353/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.k_proj.weight]
# Loading weights:  89% 353/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.k_proj.weight]
# Loading weights:  89% 354/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.bias]
# Loading weights:  89% 354/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.bias]
# Loading weights:  90% 355/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.weight]
# Loading weights:  90% 355/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.weight]
# Loading weights:  90% 356/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.bias]
# Loading weights:  90% 356/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.bias]
# Loading weights:  90% 357/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.weight]
# Loading weights:  90% 357/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.weight]
# Loading weights:  90% 358/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.bias]
# Loading weights:  90% 358/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.bias]
# Loading weights:  91% 359/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.weight]
# Loading weights:  91% 359/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.weight]
# Loading weights:  91% 360/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.bias]
# Loading weights:  91% 360/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.bias]
# Loading weights:  91% 361/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.weight]
# Loading weights:  91% 361/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.weight]
# Loading weights:  91% 362/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.bias]
# Loading weights:  91% 362/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.bias]
# Loading weights:  92% 363/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.weight]
# Loading weights:  92% 363/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.weight]
# Loading weights:  92% 364/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.bias]
# Loading weights:  92% 364/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.bias]
# Loading weights:  92% 365/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.weight]
# Loading weights:  92% 365/396 [00:04<00:00, 80.06it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.weight]
# Loading weights:  92% 366/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.weight]
# Loading weights:  92% 366/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.bias]
# Loading weights:  92% 366/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.bias]
# Loading weights:  93% 367/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.weight]
# Loading weights:  93% 367/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.weight]
# Loading weights:  93% 368/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.bias]
# Loading weights:  93% 368/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.bias]
# Loading weights:  93% 369/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.weight]
# Loading weights:  93% 369/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.weight]
# Loading weights:  93% 370/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.bias]
# Loading weights:  93% 370/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.bias]
# Loading weights:  94% 371/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.weight]
# Loading weights:  94% 371/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.weight]
# Loading weights:  94% 372/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.bias]
# Loading weights:  94% 372/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.bias]
# Loading weights:  94% 373/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.weight]
# Loading weights:  94% 373/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.weight]
# Loading weights:  94% 374/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.bias]
# Loading weights:  94% 374/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.bias]
# Loading weights:  95% 375/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.weight]
# Loading weights:  95% 375/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.weight]
# Loading weights:  95% 376/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.bias]
# Loading weights:  95% 376/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.bias]
# Loading weights:  95% 377/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.weight]
# Loading weights:  95% 377/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.weight]
# Loading weights:  95% 378/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.bias]
# Loading weights:  95% 378/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.bias]
# Loading weights:  96% 379/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.weight]
# Loading weights:  96% 379/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.weight]
# Loading weights:  96% 380/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.bias]
# Loading weights:  96% 380/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.bias]
# Loading weights:  96% 381/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.weight]
# Loading weights:  96% 381/396 [00:04<00:00, 80.01it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.weight]
# Loading weights:  96% 382/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.weight]
# Loading weights:  96% 382/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.bias]
# Loading weights:  96% 382/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.bias]
# Loading weights:  97% 383/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.weight]
# Loading weights:  97% 383/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.weight]
# Loading weights:  97% 384/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.bias]
# Loading weights:  97% 384/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.bias]
# Loading weights:  97% 385/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.weight]
# Loading weights:  97% 385/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.weight]
# Loading weights:  97% 386/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.bias]
# Loading weights:  97% 386/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.bias]
# Loading weights:  98% 387/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.weight]
# Loading weights:  98% 387/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.weight]
# Loading weights:  98% 388/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.bias]
# Loading weights:  98% 388/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.bias]
# Loading weights:  98% 389/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.weight]
# Loading weights:  98% 389/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.weight]
# Loading weights:  98% 390/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.bias]
# Loading weights:  98% 390/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.bias]
# Loading weights:  99% 391/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.weight]
# Loading weights:  99% 391/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.weight]
# Loading weights:  99% 392/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.post_layernorm.bias]
# Loading weights:  99% 392/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.post_layernorm.bias]
# Loading weights:  99% 393/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.post_layernorm.weight]
# Loading weights:  99% 393/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.post_layernorm.weight]
# Loading weights:  99% 394/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.pre_layrnorm.bias]
# Loading weights:  99% 394/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.pre_layrnorm.bias]
# Loading weights: 100% 395/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.pre_layrnorm.weight]
# Loading weights: 100% 395/396 [00:04<00:00, 80.19it/s, Materializing param=vision_model.vision_model.pre_layrnorm.weight]
# Loading weights: 100% 396/396 [00:04<00:00, 80.19it/s, Materializing param=visual_projection.weight]
# Loading weights: 100% 396/396 [00:04<00:00, 82.63it/s, Materializing param=visual_projection.weight]
# StableDiffusionSafetyChecker LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71% 5/7 [00:22<00:09,  4.87s/it]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:22<00:00,  3.19s/it]
# Loading unet.
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# Steps: 100% 1200/1200 [25:36<00:00,  1.28s/it, loss=0.00203, lr=0.0001]

# %%
pip install bitsandbytes
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.2)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (1.26.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3,>=2.3->bitsandbytes) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)

# %%
import os
model_dir = "/content/lora_sticker_model"
print("exist?", os.path.exists(model_dir))
# Out:
# exist? True

# %% [markdown]
# # Step 5: Testing

# %%
# !pip uninstall -y diffusers
# !pip install diffusers[torch] --upgrade
# Out:
# Found existing installation: diffusers 0.38.0.dev0
# Uninstalling diffusers-0.38.0.dev0:
#   Successfully uninstalled diffusers-0.38.0.dev0
# Collecting diffusers[torch]
#   Downloading diffusers-0.37.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (3.25.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (1.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (0.8.0rc0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (11.3.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (2.10.0+cu128)
# Requirement already satisfied: accelerate>=0.31.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (1.13.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers[torch]) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers[torch]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers[torch]) (6.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[torch]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[torch]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[torch]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers[torch]) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.4->diffusers[torch]) (1.5.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->diffusers[torch]) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers[torch]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers[torch]) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4->diffusers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4->diffusers[torch]) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.1.2)
# Downloading diffusers-0.37.1-py3-none-any.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 74.0 MB/s eta 0:00:00
# Installing collected packages: diffusers
# Successfully installed diffusers-0.37.1

# %%
from diffusers import StableDiffusionPipeline
import torch
# loading models
pipe=StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
).to("cuda")
pipe.unet.load_attn_procs("/content/lora_sticker_model")
# pipe.unet.load_attn_procs("/content/lora_sticker_model/checkpoint-400")
# generating pictures
animal = "cat"
prompt = f"a sks {animal} sticker style"
image = pipe(prompt, num_inference_steps=50).images[0]
image
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# StableDiffusionSafetyChecker LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# # Step 6: Save the model to the Hugging face

# %%
import os
model_dir = "/content/lora_sticker_model"
print("exsit？", os.path.exists(model_dir))
if os.path.exists(model_dir):
    print("list：", os.listdir(model_dir))
# Out:
# exsit？ True
# list： ['checkpoint-400', 'checkpoint-600', 'checkpoint-1200', 'checkpoint-800', 'checkpoint-200', 'pytorch_lora_weights.safetensors', 'checkpoint-1000', 'logs']

# %%
# !find /content -name "*.json" 2>/dev/null
# !find /content -name "*.safetensors" 2>/dev/null
# Out:
# /content/.config/.last_update_check.json
# /content/sample_data/anscombe.json
# /content/lora_sticker_model/checkpoint-400/pytorch_lora_weights.safetensors
# /content/lora_sticker_model/checkpoint-600/pytorch_lora_weights.safetensors
# /content/lora_sticker_model/checkpoint-1200/pytorch_lora_weights.safetensors
# /content/lora_sticker_model/checkpoint-800/pytorch_lora_weights.safetensors
# /content/lora_sticker_model/checkpoint-200/pytorch_lora_weights.safetensors
# /content/lora_sticker_model/pytorch_lora_weights.safetensors
# /content/lora_sticker_model/checkpoint-1000/pytorch_lora_weights.safetensors

# %%
import json
import os

model_dir = "/content/lora_sticker_model"
config = {
    "base_model_name_or_path": "runwayml/stable-diffusion-v1-5",
    "revision": None,
    "rank": 8,
    "alpha": 16,
    "dropout": 0.1,
    "target_modules": ["to_q", "to_k", "to_v", "to_out.0"]
}
with open(os.path.join(model_dir, "adapter_config.json"), "w") as f:
    json.dump(config, f, indent=2)

print("adapter_config.json existed", model_dir)
# Out:
# adapter_config.json existed /content/lora_sticker_model

# %%
from google.colab import files

files.download(os.path.join(model_dir, "pytorch_lora_weights.safetensors"))
files.download(os.path.join(model_dir, "adapter_config.json"))

# %%
import zipfile
import os
folder_path = "/content/lora_sticker_model"
zip_filename = "lora_sticker_model.zip"
with zipfile.ZipFile(zip_filename, "w", zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            arcname = os.path.relpath(file_path, folder_path)
            zipf.write(file_path, arcname)

from google.colab import files
files.download(zip_filename)

# %%
from diffusers import StableDiffusionPipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16).to("cuda")
pipe.unet.load_attn_procs("Lilian0703/sticker-lora-watercolor")
image = pipe("a cute dog, <sks> style").images[0]
image
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# StableDiffusionSafetyChecker LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

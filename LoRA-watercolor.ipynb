# %% [markdown]
# <a href="https://colab.research.google.com/github/lilian0703/stat-6209-topic-3-project/blob/main/LoRA-watercolor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1: Install the environment

# %%
# !pip uninstall -y torch torchvision torchaudio xformers

# %%
# 安装 PyTorch 2.5.1+cu124（或更新版本）
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp312-cp312-linux_x86_64.whl.metadata (28 kB)
# Collecting torchvision
#   Downloading https://download-r2.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp312-cp312-linux_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading https://download-r2.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp312-cp312-linux_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Using cached https://download.pytorch.org/whl/cu124/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Using cached https://download.pytorch.org/whl/cu124/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Using cached https://download.pytorch.org/whl/cu124/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.4 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.8 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.8 MB/s eta 0:00:00
# Collecting triton==3.2.0 (from torch)
#   Downloading https://download.pytorch.org/whl/triton-3.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Collecting sympy==1.13.1 (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Downloading https://download.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp312-cp312-linux_x86_64.whl (768.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 768.4/768.4 MB 1.8 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 7.3 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 72.8 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/triton-3.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (166.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.7/166.7 MB 6.8 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp312-cp312-linux_x86_64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 80.6 MB/s eta 0:00:00
# Downloading https://download-r2.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp312-cp312-linux_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 87.0 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: triton, nvidia-cusparselt-cu12, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: nvidia-cusparselt-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: sympy
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-curand-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: nvidia-cusolver-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12234/723820235.py in <cell line: 0>()
#       1 # 安装 PyTorch 2.5.1+cu124（或更新版本）
# ----> 2 get_ipython().system('pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97
#      98     if pip_warn:
# ---> 99       _pip.print_previous_import_warning(output)
#     100
#     101   def _send_error(self, exc_content):
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in print_previous_import_warning(output)
#      54 def print_previous_import_warning(output):
#      55   """Prints a warning about previously imported packages."""
# ---> 56   packages = _previously_imported_packages(output)
#      57   if packages:
#      58     # display a list of packages using the colab-display-data mimetype, which
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in _previously_imported_packages(pip_output)
#      48 def _previously_imported_packages(pip_output):
#      49   """List all previously imported packages from a pip install."""
# ---> 50   installed = set(_extract_toplevel_packages(pip_output))
#      51   return sorted(installed.intersection(set(sys.modules)))
#      52
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in _extract_toplevel_packages(pip_output)
#      37   """Extract the list of toplevel packages associated with a pip install."""
#      38   toplevel = collections.defaultdict(set)
# ---> 39   for m, ps in importlib.metadata.packages_distributions().items():
#      40     for p in ps:
#      41       toplevel[p].add(m)
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in packages_distributions()
#     946     for dist in distributions():
#     947         for pkg in _top_level_declared(dist) or _top_level_inferred(dist):
# --> 948             pkg_to_dist[pkg].append(dist.metadata['Name'])
#     949     return dict(pkg_to_dist)
#     950
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in metadata(self)
#     450         )
#     451         text = cast(str, opt_text)
# --> 452         return _adapters.Message(email.message_from_string(text))
#     453
#     454     @property
#
# /usr/lib/python3.12/email/__init__.py in message_from_string(s, *args, **kws)
#      35     """
#      36     from email.parser import Parser
# ---> 37     return Parser(*args, **kws).parsestr(s)
#      38
#      39 def message_from_bytes(s, *args, **kws):
#
# /usr/lib/python3.12/email/parser.py in parsestr(self, text, headersonly)
#      62         the file.
#      63         """
# ---> 64         return self.parse(StringIO(text), headersonly=headersonly)
#      65
#      66
#
# /usr/lib/python3.12/email/parser.py in parse(self, fp, headersonly)
#      51             feedparser._set_headersonly()
#      52         while data := fp.read(8192):
# ---> 53             feedparser.feed(data)
#      54         return feedparser.close()
#      55
#
# /usr/lib/python3.12/email/feedparser.py in feed(self, data)
#     172         """Push more data into the parser."""
#     173         self._input.push(data)
# --> 174         self._call_parse()
#     175
#     176     def _call_parse(self):
#
# /usr/lib/python3.12/email/feedparser.py in _call_parse(self)
#     176     def _call_parse(self):
#     177         try:
# --> 178             self._parse()
#     179         except StopIteration:
#     180             pass
#
# /usr/lib/python3.12/email/feedparser.py in _parsegen(self)
#     236         # Done with the headers, so parse them and figure out what we're
#     237         # supposed to see in the body of the message.
# --> 238         self._parse_headers(headers)
#     239         # Headers-only parsing is a backwards compatibility hack, which was
#     240         # necessary in the older parser, which could raise errors.  All
#
# /usr/lib/python3.12/email/feedparser.py in _parse_headers(self, lines)
#     484                 continue
#     485             if lastheader:
# --> 486                 self._cur.set_raw(*self.policy.header_source_parse(lastvalue))
#     487                 lastheader, lastvalue = '', []
#     488             # Check for envelope header, i.e. unix-from
#
# /usr/lib/python3.12/email/_policybase.py in header_source_parse(self, sourcelines)
#     308         """
#     309         name, value = sourcelines[0].split(':', 1)
# --> 310         value = ''.join((value, *sourcelines[1:])).lstrip(' \t\r\n')
#     311         return (name, value.rstrip('\r\n'))
#     312
#
# KeyboardInterrupt:

# %%
# !nvidia-smi
# !pip install --upgrade protobuf==5.29.1
# !pip install numpy==1.26.0
# !pip install wandb==0.16.3
# !pip install --upgrade accelerate diffusers[training]
# !pip install -q transformers datasets peft bitsandbytes xformers huggingface_hub
# Out:
# Thu Mar 19 14:36:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Collecting protobuf==5.29.1
#   Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 23.9 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# Successfully installed protobuf-5.29.1
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Collecting numpy==1.26.0
#   Downloading numpy-1.26.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 2.1 MB/s eta 0:00:00
# Downloading numpy-1.26.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 21.1 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bitsandbytes 0.49.2 requires torch<3,>=2.3, which is not installed.
# fastai 2.8.7 requires torch<3,>=1.10, which is not installed.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.
# peft 0.18.1 requires torch>=1.13.0, which is not installed.
# sentence-transformers 5.3.0 requires torch>=1.11.0, which is not installed.
# accelerate 1.13.0 requires torch>=2.0.0, which is not installed.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.0 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.0 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.0 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.0 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.0 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.0 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.0 which is incompatible.
# Successfully installed numpy-1.26.0
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Collecting wandb==0.16.3
#   Downloading wandb-0.16.3-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (8.3.1)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (3.1.46)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (2.32.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (2.54.0)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.16.3)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (6.0.3)
# Collecting setproctitle (from wandb==0.16.3)
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.3) (75.2.0)
# Collecting appdirs>=1.4.3 (from wandb==0.16.3)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting protobuf!=4.21.0,<5,>=3.19.0 (from wandb==0.16.3)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from docker-pycreds>=0.4.0->wandb==0.16.3) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.3) (4.0.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.3) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.3) (2026.2.25)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.3) (5.0.3)
# Downloading wandb-0.16.3-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 68.1 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 32.5 MB/s eta 0:00:00
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: appdirs, setproctitle, protobuf, docker-pycreds, wandb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.1
#     Uninstalling protobuf-5.29.1:
#       Successfully uninstalled protobuf-5.29.1
#   Attempting uninstall: wandb
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: wandb 0.25.1
#     Uninstalling wandb-0.25.1:
#       Successfully uninstalled wandb-0.25.1
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.8 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# Successfully installed appdirs-1.4.4 docker-pycreds-0.4.0 protobuf-4.25.8 setproctitle-1.3.7 wandb-0.16.3
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: diffusers[training] in /usr/local/lib/python3.12/dist-packages (0.37.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Collecting torch>=2.0.0 (from accelerate)
#   Downloading torch-2.10.0-3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (1.7.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (3.25.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (2.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (11.3.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (4.0.0)
# Collecting protobuf<4,>=3.20.3 (from diffusers[training])
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (2.19.0)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (3.1.6)
# Requirement already satisfied: peft>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (0.18.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from diffusers[training]) (1.0.25)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[training]) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[training]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[training]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[training]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers[training]) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft>=0.17.0->diffusers[training]) (5.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Collecting sympy>=1.13.3 (from torch>=2.0.0->accelerate)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.9.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.5)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Collecting triton==3.6.0 (from torch>=2.0.0->accelerate)
#   Downloading triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate) (1.4.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->diffusers[training]) (0.70.16)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers[training]) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers[training]) (2.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers[training]) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2->diffusers[training]) (3.0.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (3.10.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->diffusers[training]) (3.1.6)
# Collecting torchvision (from timm->diffusers[training])
#   Downloading torchvision-0.25.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (3.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->diffusers[training]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->diffusers[training]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->diffusers[training]) (2025.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->peft>=0.17.0->diffusers[training]) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->peft>=0.17.0->diffusers[training]) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->diffusers[training]) (1.23.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 11.5 MB/s eta 0:00:00
# Downloading torch-2.10.0-3-cp312-cp312-manylinux_2_28_x86_64.whl (915.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.6/915.6 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 110.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 54.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 22.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.9 MB/s eta 0:00:00
# Downloading triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.2 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 98.2 MB/s eta 0:00:00
# Downloading torchvision-0.25.0-cp312-cp312-manylinux_2_28_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 93.3 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: nvidia-cusparselt-cu12, triton, sympy, protobuf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: nvidia-cusparselt-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: triton
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.8
#     Uninstalling protobuf-4.25.8:
#       Successfully uninstalled protobuf-4.25.8
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: nvidia-cusparse-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-cufft-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: nvidia-cusolver-cu12
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.17.3 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# google-api-core 2.30.0 requires protobuf<7.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 protobuf-3.20.3 sympy-1.14.0 torch torchvision-0.25.0 triton-3.6.0
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 70.6 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)

# %% [markdown]
# # Step 2: Upload and check the training data

# %%
import os
image_dir = "/content/sticker_images"
os.makedirs(image_dir, exist_ok=True)

# %%
images = os.listdir(image_dir)
print(f"find {len(images)} picturs：{images[:]}")
if len(images) == 0:
    raise Exception("upload /content/sticker_images first！")

# %% [markdown]
# # Step 3: Diffusers

# %%
import os
os.environ["WANDB_DISABLED"] = "true"
# !git clone https://github.com/huggingface/diffusers.git
# %cd /content/diffusers

# %% [markdown]
# # Step 4: Training Lora

# %%
# %cd /content/diffusers
# !pip install -e ".[torch]"
import diffusers
# Out:
# /content/diffusers
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (3.25.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (1.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (1.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (0.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (11.3.0)
# Collecting torch>=1.4 (from diffusers==0.38.0.dev0)
#   Using cached torch-2.10.0-3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: accelerate>=0.31.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.38.0.dev0) (1.13.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers==0.38.0.dev0) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers==0.38.0.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers==0.38.0.dev0) (6.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.38.0.dev0) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.38.0.dev0) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.38.0.dev0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.38.0.dev0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers==0.38.0.dev0) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers==0.38.0.dev0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.4->diffusers==0.38.0.dev0) (1.4.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers==0.38.0.dev0) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.38.0.dev0) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.38.0.dev0) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4->diffusers==0.38.0.dev0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4->diffusers==0.38.0.dev0) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.38.0.dev0) (0.1.2)
# Using cached torch-2.10.0-3-cp312-cp312-manylinux_2_28_x86_64.whl (915.6 MB)
# Building wheels for collected packages: diffusers
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.38.0.dev0-0.editable-py3-none-any.whl size=11388 sha256=aaf849dae3efc13e0c044166da9c00029865aaadc995d1b1623c82a683613cde
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e9fo11ak/wheels/8a/fc/09/385efb77b455b2fd4a656c950079c93147e1f50ae614e51beb
# Successfully built diffusers
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: torch, diffusers
#   Attempting uninstall: diffusers
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: diffusers 0.37.0
#     Uninstalling diffusers-0.37.0:
#       Successfully uninstalled diffusers-0.37.0
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Successfully installed diffusers-0.38.0.dev0 torch

# %%
# clean the history
# !rm -rf /content/lora_sticker_model

# confirm the parameters
# !python examples/dreambooth/train_dreambooth_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --instance_data_dir="/content/sticker_images" \
  --output_dir="/content/lora_sticker_model" \
  --instance_prompt="a sticker in <sticker-style> style" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=1200 \
  --mixed_precision="fp16" \
  --use_8bit_adam
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:206: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# {'clip_sample_range', 'prediction_type', 'dynamic_thresholding_ratio', 'variance_type', 'rescale_betas_zero_snr', 'sample_max_value', 'thresholding', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loading weights: 100% 196/196 [00:00<00:00, 565.16it/s, Materializing param=text_model.final_layer_norm.weight]
# CLIPTextModel LOAD REPORT from: runwayml/stable-diffusion-v1-5
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# {'latents_mean', 'latents_std', 'use_post_quant_conv', 'scaling_factor', 'use_quant_conv', 'force_upcast', 'shift_factor', 'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# {'time_embedding_dim', 'num_class_embeds', 'time_embedding_type', 'dropout', 'projection_class_embeddings_input_dim', 'class_embeddings_concat', 'resnet_skip_time_act', 'conv_in_kernel', 'cross_attention_norm', 'use_linear_projection', 'addition_embed_type', 'encoder_hid_dim_type', 'resnet_out_scale_factor', 'timestep_post_act', 'dual_cross_attention', 'addition_time_embed_dim', 'transformer_layers_per_block', 'class_embed_type', 'upcast_attention', 'encoder_hid_dim', 'mid_block_only_cross_attention', 'num_attention_heads', 'attention_type', 'mid_block_type', 'only_cross_attention', 'conv_out_kernel', 'addition_embed_type_num_heads', 'resnet_time_scale_shift', 'time_embedding_act_fn', 'reverse_transformer_layers_per_block', 'time_cond_proj_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# 2026-03-19 14:44:10.247540: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773931450.447239   15208 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773931450.500989   15208 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773931450.905225   15208 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773931450.905266   15208 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773931450.905271   15208 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773931450.905275   15208 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Steps:  42% 500/1200 [10:49<13:12,  1.13s/it, loss=0.362, lr=0.0001]Model weights saved in /content/lora_sticker_model/checkpoint-500/pytorch_lora_weights.safetensors
# Steps:  83% 1000/1200 [21:34<03:50,  1.15s/it, loss=0.0426, lr=0.0001]Model weights saved in /content/lora_sticker_model/checkpoint-1000/pytorch_lora_weights.safetensors
# Steps: 100% 1200/1200 [25:50<00:00,  1.12s/it, loss=0.0206, lr=0.0001]Model weights saved in /content/lora_sticker_model/pytorch_lora_weights.safetensors
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
#
# Loading weights:   1% 1/196 [00:00<00:00, 7681.88it/s, Materializing param=text_model.embeddings.position_embedding.weight]
#
# Loading weights:   1% 1/196 [00:00<00:00, 4429.04it/s, Materializing param=text_model.embeddings.position_embedding.weight]
#
# Loading weights:   1% 2/196 [00:00<00:00, 1563.58it/s, Materializing param=text_model.embeddings.token_embedding.weight]
#
# Loading weights:   1% 2/196 [00:00<00:00, 1386.09it/s, Materializing param=text_model.embeddings.token_embedding.weight]
#
# Loading weights:   2% 3/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.embeddings.token_embedding.weight]
#
# Loading weights:   2% 3/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.bias]
#
# Loading weights:   2% 3/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.bias]
#
# Loading weights:   2% 4/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.weight]
#
# Loading weights:   2% 4/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.weight]
#
# Loading weights:   3% 5/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.bias]
#
# Loading weights:   3% 5/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.bias]
#
# Loading weights:   3% 6/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.weight]
#
# Loading weights:   3% 6/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.weight]
#
# Loading weights:   4% 7/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.bias]
#
# Loading weights:   4% 7/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.bias]
#
# Loading weights:   4% 8/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.weight]
#
# Loading weights:   4% 8/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.weight]
#
# Loading weights:   5% 9/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.bias]
#
# Loading weights:   5% 9/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.bias]
#
# Loading weights:   5% 10/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.weight]
#
# Loading weights:   5% 10/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.weight]
#
# Loading weights:   6% 11/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.bias]
#
# Loading weights:   6% 11/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.bias]
#
# Loading weights:   6% 12/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.weight]
#
# Loading weights:   6% 12/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.weight]
#
# Loading weights:   7% 13/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.bias]
#
# Loading weights:   7% 13/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.bias]
#
# Loading weights:   7% 14/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.weight]
#
# Loading weights:   7% 14/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.weight]
#
# Loading weights:   8% 15/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.bias]
#
# Loading weights:   8% 15/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.bias]
#
# Loading weights:   8% 16/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.weight]
#
# Loading weights:   8% 16/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.weight]
#
# Loading weights:   9% 17/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.bias]
#
# Loading weights:   9% 17/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.bias]
#
# Loading weights:   9% 18/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.weight]
#
# Loading weights:   9% 18/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.weight]
#
# Loading weights:  10% 19/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.bias]
#
# Loading weights:  10% 19/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.bias]
#
# Loading weights:  10% 20/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.weight]
#
# Loading weights:  10% 20/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.weight]
#
# Loading weights:  11% 21/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.bias]
#
# Loading weights:  11% 21/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.bias]
#
# Loading weights:  11% 22/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.weight]
#
# Loading weights:  11% 22/196 [00:00<00:06, 28.99it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.weight]
#
# Loading weights:  12% 23/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.bias]
#
# Loading weights:  12% 23/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.bias]
#
# Loading weights:  12% 24/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.weight]
#
# Loading weights:  12% 24/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.weight]
#
# Loading weights:  13% 25/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.bias]
#
# Loading weights:  13% 25/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.bias]
#
# Loading weights:  13% 26/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.weight]
#
# Loading weights:  13% 26/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.weight]
#
# Loading weights:  14% 27/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.bias]
#
# Loading weights:  14% 27/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.bias]
#
# Loading weights:  14% 28/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.weight]
#
# Loading weights:  14% 28/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.weight]
#
# Loading weights:  15% 29/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.bias]
#
# Loading weights:  15% 29/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.bias]
#
# Loading weights:  15% 30/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.weight]
#
# Loading weights:  15% 30/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.weight]
#
# Loading weights:  16% 31/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.bias]
#
# Loading weights:  16% 31/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.bias]
#
# Loading weights:  16% 32/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.weight]
#
# Loading weights:  16% 32/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.weight]
#
# Loading weights:  17% 33/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.bias]
#
# Loading weights:  17% 33/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.bias]
#
# Loading weights:  17% 34/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.weight]
#
# Loading weights:  17% 34/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.weight]
#
# Loading weights:  18% 35/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.bias]
#
# Loading weights:  18% 35/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.bias]
#
# Loading weights:  18% 36/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.weight]
#
# Loading weights:  18% 36/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.weight]
#
# Loading weights:  19% 37/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.bias]
#
# Loading weights:  19% 37/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.bias]
#
# Loading weights:  19% 38/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.weight]
#
# Loading weights:  19% 38/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.weight]
#
# Loading weights:  20% 39/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.bias]
#
# Loading weights:  20% 39/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.bias]
#
# Loading weights:  20% 40/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.weight]
#
# Loading weights:  20% 40/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.weight]
#
# Loading weights:  21% 41/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.bias]
#
# Loading weights:  21% 41/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.bias]
#
# Loading weights:  21% 42/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.weight]
#
# Loading weights:  21% 42/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.weight]
#
# Loading weights:  22% 43/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.bias]
#
# Loading weights:  22% 43/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.bias]
#
# Loading weights:  22% 44/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.weight]
#
# Loading weights:  22% 44/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.weight]
#
# Loading weights:  23% 45/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.bias]
#
# Loading weights:  23% 45/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.bias]
#
# Loading weights:  23% 46/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.weight]
#
# Loading weights:  23% 46/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.weight]
#
# Loading weights:  24% 47/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.bias]
#
# Loading weights:  24% 47/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.bias]
#
# Loading weights:  24% 48/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.weight]
#
# Loading weights:  24% 48/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.weight]
#
# Loading weights:  25% 49/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.bias]
#
# Loading weights:  25% 49/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.bias]
#
# Loading weights:  26% 50/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.weight]
#
# Loading weights:  26% 50/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.weight]
#
# Loading weights:  26% 51/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.bias]
#
# Loading weights:  26% 51/196 [00:00<00:05, 28.99it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.bias]
#
# Loading weights:  27% 52/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.weight]
#
# Loading weights:  27% 52/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.weight]
#
# Loading weights:  27% 53/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.bias]
#
# Loading weights:  27% 53/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.bias]
#
# Loading weights:  28% 54/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.weight]
#
# Loading weights:  28% 54/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.weight]
#
# Loading weights:  28% 55/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.bias]
#
# Loading weights:  28% 55/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.bias]
#
# Loading weights:  29% 56/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.weight]
#
# Loading weights:  29% 56/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.weight]
#
# Loading weights:  29% 57/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.bias]
#
# Loading weights:  29% 57/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.bias]
#
# Loading weights:  30% 58/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.weight]
#
# Loading weights:  30% 58/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.weight]
#
# Loading weights:  30% 59/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.bias]
#
# Loading weights:  30% 59/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.bias]
#
# Loading weights:  31% 60/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.weight]
#
# Loading weights:  31% 60/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.weight]
#
# Loading weights:  31% 61/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.bias]
#
# Loading weights:  31% 61/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.bias]
#
# Loading weights:  32% 62/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.weight]
#
# Loading weights:  32% 62/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.weight]
#
# Loading weights:  32% 63/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.bias]
#
# Loading weights:  32% 63/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.bias]
#
# Loading weights:  33% 64/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.weight]
#
# Loading weights:  33% 64/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.weight]
#
# Loading weights:  33% 65/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.bias]
#
# Loading weights:  33% 65/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.bias]
#
# Loading weights:  34% 66/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.weight]
#
# Loading weights:  34% 66/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.weight]
#
# Loading weights:  34% 67/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.bias]
#
# Loading weights:  34% 67/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.bias]
#
# Loading weights:  35% 68/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.weight]
#
# Loading weights:  35% 68/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.weight]
#
# Loading weights:  35% 69/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.bias]
#
# Loading weights:  35% 69/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.bias]
#
# Loading weights:  36% 70/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.weight]
#
# Loading weights:  36% 70/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.weight]
#
# Loading weights:  36% 71/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.bias]
#
# Loading weights:  36% 71/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.bias]
#
# Loading weights:  37% 72/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.weight]
#
# Loading weights:  37% 72/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.weight]
#
# Loading weights:  37% 73/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.bias]
#
# Loading weights:  37% 73/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.bias]
#
# Loading weights:  38% 74/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.weight]
#
# Loading weights:  38% 74/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.weight]
#
# Loading weights:  38% 75/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.bias]
#
# Loading weights:  38% 75/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.bias]
#
# Loading weights:  39% 76/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.weight]
#
# Loading weights:  39% 76/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.weight]
#
# Loading weights:  39% 77/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.bias]
#
# Loading weights:  39% 77/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.bias]
#
# Loading weights:  40% 78/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.weight]
#
# Loading weights:  40% 78/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.weight]
#
# Loading weights:  40% 79/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.bias]
#
# Loading weights:  40% 79/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.bias]
#
# Loading weights:  41% 80/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.weight]
#
# Loading weights:  41% 80/196 [00:00<00:04, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.weight]
#
# Loading weights:  41% 81/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.bias]
#
# Loading weights:  41% 81/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.bias]
#
# Loading weights:  42% 82/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.weight]
#
# Loading weights:  42% 82/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.weight]
#
# Loading weights:  42% 83/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.bias]
#
# Loading weights:  42% 83/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.bias]
#
# Loading weights:  43% 84/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
#
# Loading weights:  43% 84/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
#
# Loading weights:  43% 85/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.bias]
#
# Loading weights:  43% 85/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.bias]
#
# Loading weights:  44% 86/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.weight]
#
# Loading weights:  44% 86/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.weight]
#
# Loading weights:  44% 87/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.bias]
#
# Loading weights:  44% 87/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.bias]
#
# Loading weights:  45% 88/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.weight]
#
# Loading weights:  45% 88/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.weight]
#
# Loading weights:  45% 89/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.bias]
#
# Loading weights:  45% 89/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.bias]
#
# Loading weights:  46% 90/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.weight]
#
# Loading weights:  46% 90/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.weight]
#
# Loading weights:  46% 91/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.bias]
#
# Loading weights:  46% 91/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.bias]
#
# Loading weights:  47% 92/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.weight]
#
# Loading weights:  47% 92/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.weight]
#
# Loading weights:  47% 93/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.bias]
#
# Loading weights:  47% 93/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.bias]
#
# Loading weights:  48% 94/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.weight]
#
# Loading weights:  48% 94/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.weight]
#
# Loading weights:  48% 95/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.bias]
#
# Loading weights:  48% 95/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.bias]
#
# Loading weights:  49% 96/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.weight]
#
# Loading weights:  49% 96/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.weight]
#
# Loading weights:  49% 97/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.bias]
#
# Loading weights:  49% 97/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.bias]
#
# Loading weights:  50% 98/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.weight]
#
# Loading weights:  50% 98/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.weight]
#
# Loading weights:  51% 99/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.bias]
#
# Loading weights:  51% 99/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.bias]
#
# Loading weights:  51% 100/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.weight]
#
# Loading weights:  51% 100/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.weight]
#
# Loading weights:  52% 101/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.bias]
#
# Loading weights:  52% 101/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.bias]
#
# Loading weights:  52% 102/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.weight]
#
# Loading weights:  52% 102/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.weight]
#
# Loading weights:  53% 103/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.bias]
#
# Loading weights:  53% 103/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.bias]
#
# Loading weights:  53% 104/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.weight]
#
# Loading weights:  53% 104/196 [00:00<00:03, 28.99it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.weight]
#
# Loading weights:  54% 105/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.weight]
#
# Loading weights:  54% 105/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.bias]
#
# Loading weights:  54% 105/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.bias]
#
# Loading weights:  54% 106/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.weight]
#
# Loading weights:  54% 106/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.weight]
#
# Loading weights:  55% 107/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.bias]
#
# Loading weights:  55% 107/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.bias]
#
# Loading weights:  55% 108/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.weight]
#
# Loading weights:  55% 108/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.weight]
#
# Loading weights:  56% 109/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.bias]
#
# Loading weights:  56% 109/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.bias]
#
# Loading weights:  56% 110/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.weight]
#
# Loading weights:  56% 110/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.weight]
#
# Loading weights:  57% 111/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.bias]
#
# Loading weights:  57% 111/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.bias]
#
# Loading weights:  57% 112/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.weight]
#
# Loading weights:  57% 112/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.weight]
#
# Loading weights:  58% 113/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.bias]
#
# Loading weights:  58% 113/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.bias]
#
# Loading weights:  58% 114/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.weight]
#
# Loading weights:  58% 114/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.weight]
#
# Loading weights:  59% 115/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.bias]
#
# Loading weights:  59% 115/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.bias]
#
# Loading weights:  59% 116/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.weight]
#
# Loading weights:  59% 116/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.weight]
#
# Loading weights:  60% 117/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.bias]
#
# Loading weights:  60% 117/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.bias]
#
# Loading weights:  60% 118/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.weight]
#
# Loading weights:  60% 118/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.weight]
#
# Loading weights:  61% 119/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.bias]
#
# Loading weights:  61% 119/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.bias]
#
# Loading weights:  61% 120/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.weight]
#
# Loading weights:  61% 120/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.weight]
#
# Loading weights:  62% 121/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.bias]
#
# Loading weights:  62% 121/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.bias]
#
# Loading weights:  62% 122/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.weight]
#
# Loading weights:  62% 122/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.weight]
#
# Loading weights:  63% 123/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.bias]
#
# Loading weights:  63% 123/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.bias]
#
# Loading weights:  63% 124/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.weight]
#
# Loading weights:  63% 124/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.weight]
#
# Loading weights:  64% 125/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.bias]
#
# Loading weights:  64% 125/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.bias]
#
# Loading weights:  64% 126/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.weight]
#
# Loading weights:  64% 126/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.weight]
#
# Loading weights:  65% 127/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.bias]
#
# Loading weights:  65% 127/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.bias]
#
# Loading weights:  65% 128/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.weight]
#
# Loading weights:  65% 128/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.weight]
#
# Loading weights:  66% 129/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.bias]
#
# Loading weights:  66% 129/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.bias]
#
# Loading weights:  66% 130/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.weight]
#
# Loading weights:  66% 130/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.weight]
#
# Loading weights:  67% 131/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.bias]
#
# Loading weights:  67% 131/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.bias]
#
# Loading weights:  67% 132/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.weight]
#
# Loading weights:  67% 132/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.weight]
#
# Loading weights:  68% 133/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.bias]
#
# Loading weights:  68% 133/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.bias]
#
# Loading weights:  68% 134/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.weight]
#
# Loading weights:  68% 134/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.weight]
#
# Loading weights:  69% 135/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.bias]
#
# Loading weights:  69% 135/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.bias]
#
# Loading weights:  69% 136/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.weight]
#
# Loading weights:  69% 136/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.weight]
#
# Loading weights:  70% 137/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.bias]
#
# Loading weights:  70% 137/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.bias]
#
# Loading weights:  70% 138/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.weight]
#
# Loading weights:  70% 138/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.weight]
#
# Loading weights:  71% 139/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.bias]
#
# Loading weights:  71% 139/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.bias]
#
# Loading weights:  71% 140/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.weight]
#
# Loading weights:  71% 140/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.weight]
#
# Loading weights:  72% 141/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.bias]
#
# Loading weights:  72% 141/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.bias]
#
# Loading weights:  72% 142/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.weight]
#
# Loading weights:  72% 142/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.weight]
#
# Loading weights:  73% 143/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.bias]
#
# Loading weights:  73% 143/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.bias]
#
# Loading weights:  73% 144/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.weight]
#
# Loading weights:  73% 144/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.weight]
#
# Loading weights:  74% 145/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.bias]
#
# Loading weights:  74% 145/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.bias]
#
# Loading weights:  74% 146/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.weight]
#
# Loading weights:  74% 146/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.weight]
#
# Loading weights:  75% 147/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.bias]
#
# Loading weights:  75% 147/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.bias]
#
# Loading weights:  76% 148/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.weight]
#
# Loading weights:  76% 148/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.weight]
#
# Loading weights:  76% 149/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.bias]
#
# Loading weights:  76% 149/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.bias]
#
# Loading weights:  77% 150/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.weight]
#
# Loading weights:  77% 150/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.weight]
#
# Loading weights:  77% 151/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.mlp.fc1.bias]
#
# Loading weights:  77% 151/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.mlp.fc1.bias]
#
# Loading weights:  78% 152/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.mlp.fc1.weight]
#
# Loading weights:  78% 152/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.mlp.fc1.weight]
#
# Loading weights:  78% 153/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.mlp.fc2.bias]
#
# Loading weights:  78% 153/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.mlp.fc2.bias]
#
# Loading weights:  79% 154/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.mlp.fc2.weight]
#
# Loading weights:  79% 154/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.mlp.fc2.weight]
#
# Loading weights:  79% 155/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.k_proj.bias]
#
# Loading weights:  79% 155/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.k_proj.bias]
#
# Loading weights:  80% 156/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.k_proj.weight]
#
# Loading weights:  80% 156/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.k_proj.weight]
#
# Loading weights:  80% 157/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.out_proj.bias]
#
# Loading weights:  80% 157/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.out_proj.bias]
#
# Loading weights:  81% 158/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.out_proj.weight]
#
# Loading weights:  81% 158/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.out_proj.weight]
#
# Loading weights:  81% 159/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.q_proj.bias]
#
# Loading weights:  81% 159/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.q_proj.bias]
#
# Loading weights:  82% 160/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.q_proj.weight]
#
# Loading weights:  82% 160/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.q_proj.weight]
#
# Loading weights:  82% 161/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.v_proj.bias]
#
# Loading weights:  82% 161/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.v_proj.bias]
#
# Loading weights:  83% 162/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.v_proj.weight]
#
# Loading weights:  83% 162/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.9.self_attn.v_proj.weight]
#
# Loading weights:  83% 163/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.10.layer_norm1.bias]
#
# Loading weights:  83% 163/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.10.layer_norm1.bias]
#
# Loading weights:  84% 164/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.10.layer_norm1.weight]
#
# Loading weights:  84% 164/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.10.layer_norm1.weight]
#
# Loading weights:  84% 165/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.bias]
#
# Loading weights:  84% 165/196 [00:00<00:00, 600.48it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.bias]
#
# Loading weights:  85% 166/196 [00:00<00:00, 583.96it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.bias]
#
# Loading weights:  85% 166/196 [00:00<00:00, 583.96it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.weight]
#
# Loading weights:  85% 166/196 [00:00<00:00, 583.96it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.weight]
#
# Loading weights:  85% 167/196 [00:00<00:00, 583.96it/s, Materializing param=text_model.encoder.layers.10.mlp.fc1.bias]
#
# ...
#
# Loading weights:  89% 354/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.bias]
#
# Loading weights:  90% 355/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.weight]
#
# Loading weights:  90% 355/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.weight]
#
# Loading weights:  90% 356/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.bias]
#
# Loading weights:  90% 356/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.bias]
#
# Loading weights:  90% 357/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.weight]
#
# Loading weights:  90% 357/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.weight]
#
# Loading weights:  90% 358/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.bias]
#
# Loading weights:  90% 358/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.bias]
#
# Loading weights:  91% 359/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.weight]
#
# Loading weights:  91% 359/396 [00:04<00:00, 83.68it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.weight]
#
# Loading weights:  91% 360/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.weight]
#
# Loading weights:  91% 360/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.bias]
#
# Loading weights:  91% 360/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.bias]
#
# Loading weights:  91% 361/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.weight]
#
# Loading weights:  91% 361/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.weight]
#
# Loading weights:  91% 362/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.bias]
#
# Loading weights:  91% 362/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.bias]
#
# Loading weights:  92% 363/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.weight]
#
# Loading weights:  92% 363/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.weight]
#
# Loading weights:  92% 364/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.bias]
#
# Loading weights:  92% 364/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.bias]
#
# Loading weights:  92% 365/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.weight]
#
# Loading weights:  92% 365/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.weight]
#
# Loading weights:  92% 366/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.bias]
#
# Loading weights:  92% 366/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.bias]
#
# Loading weights:  93% 367/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.weight]
#
# Loading weights:  93% 367/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.weight]
#
# Loading weights:  93% 368/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.bias]
#
# Loading weights:  93% 368/396 [00:04<00:00, 85.91it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.bias]
#
# Loading weights:  93% 369/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.bias]
#
# Loading weights:  93% 369/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.weight]
#
# Loading weights:  93% 369/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.weight]
#
# Loading weights:  93% 370/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.bias]
#
# Loading weights:  93% 370/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.bias]
#
# Loading weights:  94% 371/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.weight]
#
# Loading weights:  94% 371/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.weight]
#
# Loading weights:  94% 372/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.bias]
#
# Loading weights:  94% 372/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.bias]
#
# Loading weights:  94% 373/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.weight]
#
# Loading weights:  94% 373/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.weight]
#
# Loading weights:  94% 374/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.bias]
#
# Loading weights:  94% 374/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.bias]
#
# Loading weights:  95% 375/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.weight]
#
# Loading weights:  95% 375/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.weight]
#
# Loading weights:  95% 376/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.bias]
#
# Loading weights:  95% 376/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.bias]
#
# Loading weights:  95% 377/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.weight]
#
# Loading weights:  95% 377/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.weight]
#
# Loading weights:  95% 378/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.bias]
#
# Loading weights:  95% 378/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.bias]
#
# Loading weights:  96% 379/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.weight]
#
# Loading weights:  96% 379/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.weight]
#
# Loading weights:  96% 380/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.bias]
#
# Loading weights:  96% 380/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.bias]
#
# Loading weights:  96% 381/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.weight]
#
# Loading weights:  96% 381/396 [00:04<00:00, 81.70it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.weight]
#
# Loading weights:  96% 382/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.weight]
#
# Loading weights:  96% 382/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.bias]
#
# Loading weights:  96% 382/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.bias]
#
# Loading weights:  97% 383/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.weight]
#
# Loading weights:  97% 383/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.weight]
#
# Loading weights:  97% 384/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.bias]
#
# Loading weights:  97% 384/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.bias]
#
# Loading weights:  97% 385/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.weight]
#
# Loading weights:  97% 385/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.weight]
#
# Loading weights:  97% 386/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.bias]
#
# Loading weights:  97% 386/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.bias]
#
# Loading weights:  98% 387/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.weight]
#
# Loading weights:  98% 387/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.weight]
#
# Loading weights:  98% 388/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.bias]
#
# Loading weights:  98% 388/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.bias]
#
# Loading weights:  98% 389/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.weight]
#
# Loading weights:  98% 389/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.weight]
#
# Loading weights:  98% 390/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.bias]
#
# Loading weights:  98% 390/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.bias]
#
# Loading weights:  99% 391/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.weight]
#
# Loading weights:  99% 391/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.weight]
#
# Loading weights:  99% 392/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.post_layernorm.bias]
#
# Loading weights:  99% 392/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.post_layernorm.bias]
#
# Loading weights:  99% 393/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.post_layernorm.weight]
#
# Loading weights:  99% 393/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.post_layernorm.weight]
#
# Loading weights:  99% 394/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.pre_layrnorm.bias]
#
# Loading weights:  99% 394/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.pre_layrnorm.bias]
#
# Loading weights: 100% 395/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.pre_layrnorm.weight]
#
# Loading weights: 100% 395/396 [00:04<00:00, 80.61it/s, Materializing param=vision_model.vision_model.pre_layrnorm.weight]
#
# Loading weights: 100% 396/396 [00:04<00:00, 80.61it/s, Materializing param=visual_projection.weight]
#
# Loading weights: 100% 396/396 [00:04<00:00, 80.12it/s, Materializing param=visual_projection.weight]
# StableDiffusionSafetyChecker LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:05<00:05,  1.84s/it]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  71% 5/7 [00:05<00:02,  1.29s/it]Instantiating UNet2DConditionModel model under default dtype torch.float16.
# {'time_embedding_dim', 'num_class_embeds', 'time_embedding_type', 'dropout', 'projection_class_embeddings_input_dim', 'class_embeddings_concat', 'resnet_skip_time_act', 'conv_in_kernel', 'cross_attention_norm', 'use_linear_projection', 'addition_embed_type', 'encoder_hid_dim_type', 'resnet_out_scale_factor', 'timestep_post_act', 'dual_cross_attention', 'addition_time_embed_dim', 'transformer_layers_per_block', 'class_embed_type', 'upcast_attention', 'encoder_hid_dim', 'mid_block_only_cross_attention', 'num_attention_heads', 'attention_type', 'mid_block_type', 'only_cross_attention', 'conv_out_kernel', 'addition_embed_type_num_heads', 'resnet_time_scale_shift', 'time_embedding_act_fn', 'reverse_transformer_layers_per_block', 'time_cond_proj_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  86% 6/7 [00:20<00:05,  5.42s/it]Instantiating AutoencoderKL model under default dtype torch.float16.
# {'latents_mean', 'latents_std', 'use_post_quant_conv', 'scaling_factor', 'use_quant_conv', 'force_upcast', 'shift_factor', 'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:21<00:00,  3.12s/it]
# Loading unet.
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# Steps: 100% 1200/1200 [26:14<00:00,  1.31s/it, loss=0.0206, lr=0.0001]

# %%
pip install bitsandbytes

# %%
import os
model_dir = "/content/lora_sticker_model"
print("exist?", os.path.exists(model_dir))
# Out:
# exist? True

# %% [markdown]
# # Step 5: Testing

# %%
# !pip uninstall -y diffusers
# !pip install diffusers[torch] --upgrade
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: diffusers 0.38.0.dev0
# Uninstalling diffusers-0.38.0.dev0:
#   Successfully uninstalled diffusers-0.38.0.dev0
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Collecting diffusers[torch]
#   Using cached diffusers-0.37.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (3.25.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (1.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (1.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (0.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (11.3.0)
# Collecting torch>=1.4 (from diffusers[torch])
#   Using cached torch-2.10.0-3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: accelerate>=0.31.0 in /usr/local/lib/python3.12/dist-packages (from diffusers[torch]) (1.13.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers[torch]) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers[torch]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.31.0->diffusers[torch]) (6.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[torch]) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[torch]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[torch]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers[torch]) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->diffusers[torch]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.4->diffusers[torch]) (1.4.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers[torch]) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers[torch]) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers[torch]) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4->diffusers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4->diffusers[torch]) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.1.2)
# Using cached torch-2.10.0-3-cp312-cp312-manylinux_2_28_x86_64.whl (915.6 MB)
# Using cached diffusers-0.37.0-py3-none-any.whl (5.0 MB)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: torch, diffusers
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Successfully installed diffusers-0.37.0 torch

# %%
from diffusers import StableDiffusionPipeline
import torch
# loading models
pipe=StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
).to("cuda")
pipe.unet.load_attn_procs("/content/lora_sticker_model")

# generating pictures
prompt="a cute cat, <sticker-style> style, vibrant colors, sticker design, white background"
image=pipe(prompt, num_inference_steps=50).images[0]
image
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# StableDiffusionSafetyChecker LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# # Step 6: Save the model to the Hugging face

# %%
import os
model_dir = "/content/lora_sticker_model"
print("exsit？", os.path.exists(model_dir))
if os.path.exists(model_dir):
    print("list：", os.listdir(model_dir))
# Out:
# exsit？ True
# list： ['checkpoint-1000', 'checkpoint-500', 'logs', 'pytorch_lora_weights.safetensors']

# %%
# !find /content -name "*.json" 2>/dev/null
# !find /content -name "*.safetensors" 2>/dev/null
# Out:
# /content/.config/.last_update_check.json
# /content/sample_data/anscombe.json
# /content/lora_sticker_model/checkpoint-1000/pytorch_lora_weights.safetensors
# /content/lora_sticker_model/checkpoint-500/pytorch_lora_weights.safetensors
# /content/lora_sticker_model/pytorch_lora_weights.safetensors

# %%
import json
import os

model_dir = "/content/lora_sticker_model"
config = {
    "base_model_name_or_path": "runwayml/stable-diffusion-v1-5",
    "revision": None,
    "rank": 8,
    "alpha": 16,
    "dropout": 0.1,
    "target_modules": ["to_q", "to_k", "to_v", "to_out.0"]
}
with open(os.path.join(model_dir, "adapter_config.json"), "w") as f:
    json.dump(config, f, indent=2)

print("adapter_config.json existed", model_dir)
# Out:
# adapter_config.json existed /content/lora_sticker_model

# %%
from google.colab import files

files.download(os.path.join(model_dir, "pytorch_lora_weights.safetensors"))
files.download(os.path.join(model_dir, "adapter_config.json"))

# %%
from diffusers import StableDiffusionPipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16).to("cuda")
pipe.unet.load_attn_procs("Lilian0703/sticker-lora-watercolor")
image = pipe("a cute dog, <sticker-style> style").images[0]
image
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# StableDiffusionSafetyChecker LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
